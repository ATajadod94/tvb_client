# %%
import ipywidgets as widgets

# %%
widgets.IntSlider()
# Out:
# IntSlider(value=0)

# %%
from IPython.display import display

# %%
w = widgets.IntSlider()
display(w)
# Out:
# IntSlider(value=0)

# %%
display(w)
# Out:
# IntSlider(value=0)

# %%
w.close()

# %%
w.keys
# Out:
# ['_view_name',
#  'style',
#  'layout',
#  'orientation',
#  'min',
#  '_dom_classes',
#  'max',
#  '_model_name',
#  '_view_module',
#  '_model_module_version',
#  'value',
#  '_view_count',
#  'disabled',
#  '_view_module_version',
#  'step',
#  'continuous_update',
#  'readout_format',
#  'description_tooltip',
#  'readout',
#  '_model_module',
#  'description']

# %%
from modelling_resting_state import *

# %%
x = resting_state('resources/Node7[Public]/resting_state_hands_on/connectivity_HagmannDeco66.zip', 'resources/Node7[Public]/resting_state_hands_on/Hagmann_empFC_avg.npy')

# %%
model = mymodel()
model.local_excitatory()
model.phase_flow()

# %%
model.W = widgets.IntSlider()
model.W = 0

# %%
mymodel
# Out:
# <class modelling_resting_state.mymodel at 0x11f2e3e88>

# %%
model.local_excitatory()
model.phase_flow()

# %%
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %%
model.W = widgets.IntSlider()

# %%
def setw(x):
    model.W = x
    model.phase_plot()

# %%
model = mymodel()
model.local_excitatory()
interact(setw, x=0);

# %%
def f(x):
    return x

# %%
a = interactive(f, x=10);

# %%
a
# Out:
# aW50ZXJhY3RpdmUoY2hpbGRyZW49KEludFNsaWRlcih2YWx1ZT0xMCwgZGVzY3JpcHRpb249dSd4JywgbWF4PTMwLCBtaW49LTEwKSwgT3V0cHV0KCkpLCBfZG9tX2NsYXNzZXM9KHUnd2lkZ2XigKY=

# %%
# %%javascript
#
# let myVar = 'test'
# console.log(myVar)

# %%
# %matplotlib inline
from ipywidgets import interactive, fixed

# %%
from lorenz import solve_lorenz
w=interactive(solve_lorenz,sigma=(0.0,50.0),rho=(0.0,50.0))
w
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-34-25bd1f289889> in <module>()
# ----> 1 from lorenz import solve_lorenz
#       2 w=interactive(solve_lorenz,sigma=(0.0,50.0),rho=(0.0,50.0))
#       3 w
#
# ImportError: No module named lorenz
